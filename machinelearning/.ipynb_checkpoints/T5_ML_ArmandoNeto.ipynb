# %%
path = '/home/turma02/Imagens/dc_small/'

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50 , preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2025-01-17 16:29:35.388437: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 16:29:35.398476: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737145775.410763   15934 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737145775.414211   15934 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 16:29:35.426641: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
modelo = ResNet50(weights = 'imagenet')
# Out:
# 2025-01-17 16:29:38.547995: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-01-17 16:29:38.548042: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: suporte-Legion-Slim-5-16IRH8
# 2025-01-17 16:29:38.548046: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: suporte-Legion-Slim-5-16IRH8
# 2025-01-17 16:29:38.548225: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 550.120.0
# 2025-01-17 16:29:38.548244: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 550.120.0
# 2025-01-17 16:29:38.548247: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 550.120.0

# %%
img= path + 'violao.jpeg'

# %%
img= image.load_img(img,target_size= (224,224))

# %%
plt.imshow(img)

# %%
img_p=image.img_to_array(img)
img_p = np.expand_dims(img_p,axis =0)
img_p = preprocess_input(img_p)

# %%
preds = modelo.predict(img_p)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step

# %%
print('Prediçoes: ', decode_predictions(preds,top = 5)[0])
# Out:
# Prediçoes:  [('n02676566', 'acoustic_guitar', np.float32(0.9014806)), ('n03272010', 'electric_guitar', np.float32(0.09503039)), ('n02787622', 'banjo', np.float32(0.0023298564)), ('n04536866', 'violin', np.float32(0.00044282383)), ('n03929660', 'pick', np.float32(0.00038735216))]

# %%
import os 
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D,Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2025-01-17 16:54:09.597317: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 16:54:09.606918: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737147249.619394   18875 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737147249.623160   18875 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 16:54:09.635878: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
num_classes=2

# %%
tf.random.set_seed(0)

# %%
modelo_base = ResNet50(weights = 'imagenet', include_top = False, input_shape = (224,224,3))
# Out:
# 2025-01-17 16:54:13.585420: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-01-17 16:54:13.585441: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: suporte-Legion-Slim-5-16IRH8
# 2025-01-17 16:54:13.585445: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: suporte-Legion-Slim-5-16IRH8
# 2025-01-17 16:54:13.585548: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 550.120.0
# 2025-01-17 16:54:13.585557: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 550.120.0
# 2025-01-17 16:54:13.585560: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 550.120.0

# %%
for layer in modelo_base.layers:
    layer.trainable = False

# %%
modelo = tf.keras.Sequential(
    [modelo_base,
     GlobalAveragePooling2D(),
     Dense(1024,activation = 'relu'),
     #Dropout(0.5),
     Dense(num_classes,activation='softmax')
    ])

# %%
path = '/home/turma02/Imagens/dc_small/'

# %%
def cria_dataframe(caminho):
    arquivos = []
    rotulos = []
    for arquivo in os.listdir(caminho):
        if arquivo.startswith('cat'):
            rotulos.append('cat')
        elif arquivo.startswith('dog'):
            rotulos.append('dog')
        arquivos.append(arquivo)
    return pd.DataFrame({'arquivo': arquivos,'rotulo':rotulos})

# %%
df_dados = cria_dataframe(os.path.join(path,'train'))

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   arquivo  2000 non-null   object
#  1   rotulo   2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
train_df,validation_df = train_test_split(df_dados,test_size = 0.2,
                                          stratify = df_dados['rotulo'],random_state = 0)

# %%
test_df = cria_dataframe(os.path.join(path,'test'))

# %%
train_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
validation_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df,
    directory = os.path.join(path,'train'),
    x_col = 'arquivo',
    y_col = 'rotulo',
    target_size = (224,224),
    batch_size = 64,
    class_mode = 'categorical'
)
# Out:
# Found 1600 validated image filenames belonging to 2 classes.

# %%
validation_generator = validation_datagen.flow_from_dataframe(
    validation_df,
    directory = os.path.join(path,'train'),
    x_col = 'arquivo',
    y_col = 'rotulo',
    target_size = (224,224),
    batch_size = 64,
    class_mode = 'categorical'
)
# Out:
# Found 400 validated image filenames belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_dataframe(
    test_df,
    directory = os.path.join(path,'test'),
    x_col = 'arquivo',
    y_col = 'rotulo',
    target_size = (224,224),
    batch_size = 64,
    class_mode = 'categorical'
)
# Out:
# Found 1000 validated image filenames belonging to 2 classes.

# %%
modelo.compile(optimizer = tf.keras.optimizers.Adamax(learning_rate = 0.001),
                                                    loss = 'categorical_crossentropy',
                                                    metrics = ['accuracy'])

# %%
modelo.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // train_generator.batch_size,
    validation_data= validation_generator,
    validation_steps = validation_generator.samples // validation_generator.batch_size , 
    epochs = 15
)
# Out:
# Epoch 1/15
# /home/turma02/anaconda3/envs/turma2/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7933 - loss: 1.0970 - val_accuracy: 0.9844 - val_loss: 0.0591
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.9705 - loss: 0.1049 - val_accuracy: 0.9818 - val_loss: 0.0410
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.9948 - loss: 0.0195 - val_accuracy: 0.9818 - val_loss: 0.0394
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9983 - loss: 0.0096 - val_accuracy: 0.9818 - val_loss: 0.0389
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.9979 - loss: 0.0085 - val_accuracy: 0.9844 - val_loss: 0.0279
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.9987 - loss: 0.0050 - val_accuracy: 0.9844 - val_loss: 0.0364
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9818 - val_loss: 0.0407
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9844 - val_loss: 0.0409
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9870 - val_loss: 0.0368
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9896 - val_loss: 0.0302
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9844 - val_loss: 0.0418
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9844 - val_loss: 0.0405
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9844 - val_loss: 0.0423
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9844 - val_loss: 0.0428
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9844 - val_loss: 0.0431

# %%
test_loss,test_accuracy = modelo.evaluate(test_generator,
                                              steps = test_generator.samples // test_generator.batch_size)
print(f'Acuracia no teste:{test_accuracy}')
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9812 - loss: 0.0490
# Acuracia no teste:0.9833333492279053

# %%
modelo.save('resnet_15epoch_dog_cats.keras')

# %%
def predicao_img(imagem,modelo):
    img= image.load_img(imagem, target_size = (224,224))
    img_array = image.img_to_array(img)
    img_array=np.expand_dims(img_array,axis = 0)
    img_array=preprocess_input(img_array)
    predicoes= modelo.predict(img_array)
    classes = {0:'cat',1:'dog'}
    classe_predita = classes[np.argmax(predicoes[0])]
    return classe_predita,img

# %%
amostra = path+'cachorro.jpeg'
classe_predita,img_resposta = predicao_img(amostra,modelo)
plt.figure(figsize = (3,3))
plt.imshow(img_resposta)
plt.title(f'Classe: {classe_predita}')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
amostra = path+'cat.jpeg'
classe_predita,img_resposta = predicao_img(amostra,modelo)
plt.figure(figsize = (3,3))
plt.imshow(img_resposta)
plt.title(f'Classe: {classe_predita}')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
