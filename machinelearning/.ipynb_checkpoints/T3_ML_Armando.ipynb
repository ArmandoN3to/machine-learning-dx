# %%
import pandas as pd

# %%
path='C:/Users/noturno/codigos/workshop/machine-learning-dx/machinelearning/datasets/'
cons2022=pd.read_csv(path+'consulta_cand_2022_BRASIL.csv',encoding='latin-1',sep=';')#consulta_cand_2022_BRASILsulta_cand_2022_BRASIL.csv

# %%
cons2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     664 non-null    object
#  1   HH_GERACAO                     664 non-null    object
#  2   ANO_ELEICAO                    664 non-null    int64
#  3   CD_TIPO_ELEICAO                664 non-null    int64
#  4   NM_TIPO_ELEICAO                664 non-null    object
#  5   NR_TURNO                       664 non-null    int64
#  6   CD_ELEICAO                     664 non-null    int64
#  7   DS_ELEICAO                     664 non-null    object
#  8   DT_ELEICAO                     664 non-null    object
#  9   TP_ABRANGENCIA                 664 non-null    object
#  10  SG_UF                          664 non-null    object
#  11  SG_UE                          664 non-null    object
# ...

# %%
cons2022.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  13/01/2025   03:36:23         2022                2  ELEIÇÃO ORDINÁRIA
# 1  13/01/2025   03:36:23         2022                2  ELEIÇÃO ORDINÁRIA
# 2  13/01/2025   03:36:23         2022                2  ELEIÇÃO ORDINÁRIA
# 3  13/01/2025   03:36:23         2022                2  ELEIÇÃO ORDINÁRIA
# 4  13/01/2025   03:36:23         2022                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 1         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 2         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 3         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 4         1         546  Eleições Gerais Estaduais 2022  02/10/2022
#
#   TP_ABRANGENCIA  ... CD_GRAU_INSTRUCAO    DS_GRAU_INSTRUCAO CD_ESTADO_CIVIL  \
# ...
